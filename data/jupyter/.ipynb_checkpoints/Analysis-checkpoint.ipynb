# %%
pip install pyorient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyorient

# %%
client = pyorient.OrientDB("orientdb", 2424)
session_id = client.connect("root", "fhdw")
